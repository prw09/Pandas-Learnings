# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##**Series**

# %%
data = pd.Series([0.25,0.5,0.75,1.0])
data
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# dtype: float64

# %%
data.is_unique
# Out:
# True

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
data.values
# Out:
# array([0.25, 0.5 , 0.75, 1.  ])

# %% [markdown]
# ## **Series using read_csv**

# %%
data = pd.read_csv('/content/kohli_ipl.csv',index_col='match_no')
data
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
data.head()
# Out:
#    match_no  runs
# 0         1     1
# 1         2    23
# 2         3    13
# 3         4    12
# 4         5     1

# %%
data.sample(5)
# gives a random row to get the data presentation
# it is used when there is bias in the data so you
# can use random data to get the insigths without any biases
# Out:
#      match_no  runs
# 30         31    34
# 54         55     8
# 40         41    71
# 162       163     8
# 100       101    41

# %%
data.value_counts()
# Return a Series containing counts of unique values
# Out:
# match_no  runs
# 1         1       1
# 136       10      1
# 138       20      1
# 139       6       1
# 140       5       1
#                  ..
# 76        11      1
# 77        1       1
# 78        32      1
# 79        25      1
# 215       7       1
# Name: count, Length: 215, dtype: int64

# %%
data.sort_values(inplace = False)
# Sort by the values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-4d66c7801a33> in <cell line: 1>()
# ----> 1 data.sort_values(inplace = False)
#       2 # Sort by the values
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %%
data.count()
# Out:
# runs    215
# dtype: int64

# %%
data.sum()
# Out:
# runs    6634
# dtype: int64

# %%
data.product()
# Out:
# runs    0
# dtype: int64

# %%
# mean

data.mean()
# Out:
# runs    30.855814
# dtype: float64

# %%
data.median()
# Out:
# runs    24.0
# dtype: float64

# %%
print(data.mode())
# Out:
#    runs
# 0     0

# %%
data.std()
# Out:
# runs    26.229801
# dtype: float64

# %%
data.min()
# Out:
# runs    0
# dtype: int64

# %%
data.max()
# Out:
# runs    113
# dtype: int64

# %%
data.describe()
# Out:
#              runs
# count  215.000000
# mean    30.855814
# std     26.229801
# min      0.000000
# 25%      9.000000
# 50%     24.000000
# 75%     48.000000
# max    113.000000

# %%
data[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: -1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-ae1b7cc684db> in <cell line: 1>()
# ----> 1 data[-1]
#
# ...

# %%
data
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
data[5:16]
# Out:
#           runs
# match_no
# 6            9
# 7           34
# 8            0
# 9           21
# 10           3
# 11          10
# 12          38
# 13           3
# 14          11
# 15          50
# 16           2

# %%
data[-5:]
# Out:
#           runs
# match_no
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7

# %%
print(len(data))
# Out:
# 215

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### **plotting**

# %%
data.plot()
# Out:
# <Axes: xlabel='match_no'>

# %%
data.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='runs'>

# %%
data.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
