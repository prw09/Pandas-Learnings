# %% [markdown]
# <a href="https://colab.research.google.com/github/prw09/Pandas-Learnings/blob/main/data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data1 = {
        'sales_id': [101, 201, 101, 301, 301,],
        'customer': ['Sam', 'John', 'Sam', 'Mike', 'Mike']
        }

df1 = pd.DataFrame(data1)

# %%
df1
# Out:
#    sales_id customer
# 0       101      Sam
# 1       201     John
# 2       101      Sam
# 3       301     Mike
# 4       301     Mike

# %%
df1[df1.duplicated()]
# Out:
#    sales_id customer
# 2       101      Sam
# 4       301     Mike

# %%
df1.drop_duplicates()
# Out:
#    sales_id customer
# 0       101      Sam
# 1       201     John
# 3       301     Mike

# %%
data2 = {
        'order_id': [1, 1, 2, 3],
        'product': ['iPhone 14', 'iMac 15', 'iPhone 16', 'Airpods Pro']
        }

df2 = pd.DataFrame(data2)
df2
# Out:
#    order_id      product
# 0         1    iPhone 14
# 1         1      iMac 15
# 2         2    iPhone 16
# 3         3  Airpods Pro

# %%
df1
# Out:
#    sales_id customer
# 0       101      Sam
# 1       201     John
# 2       101      Sam
# 3       301     Mike
# 4       301     Mike

# %%
df1.drop_duplicates(inplace=True)
df1
# Out:
#    sales_id customer
# 0       101      Sam
# 1       201     John
# 3       301     Mike

# %%
df2[df2.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, product]
# Index: []

# %%
df2
# Out:
#    order_id      product
# 0         1    iPhone 14
# 1         1      iMac 15
# 2         2    iPhone 16
# 3         3  Airpods Pro

# %%
df2[df2.duplicated(subset=['order_id'])]
# Out:
#    order_id  product
# 1         1  iMac 15

# %%
df2.drop_duplicates(subset=['order_id'], inplace=True)
df2
# Out:
#    order_id      product
# 0         1    iPhone 14
# 2         2    iPhone 16
# 3         3  Airpods Pro

# %%
df2.duplicated()
# Out:
# 0    False
# 2    False
# 3    False
# dtype: bool

# %%
data3 = {
        'order_id': [1, 2, 3, 4, 5],
        'product': ['iPhone 14', 'iMac 15', np.nan, 'Airpods Pro', 'iWatch'],
        'price' : [799, 1299, np.nan, np.nan, 499]
        }

df3 = pd.DataFrame(data3)
df3
# Out:
#    order_id      product   price
# 0         1    iPhone 14   799.0
# 1         2      iMac 15  1299.0
# 2         3          NaN     NaN
# 3         4  Airpods Pro     NaN
# 4         5       iWatch   499.0

# %%
df3.isnull()
# Out:
#    order_id  product  price
# 0     False    False  False
# 1     False    False  False
# 2     False     True   True
# 3     False    False   True
# 4     False    False  False

# %%
df3.isnull().sum()
# Out:
# order_id    0
# product     1
# price       2
# dtype: int64

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   order_id  5 non-null      int64
#  1   product   4 non-null      object
#  2   price     3 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 248.0+ bytes

# %%
df3.isnull().sum().sum()
# Out:
# 3

# %%
df3.dropna(subset='product', inplace=True)
df3
# Out:
#    order_id      product   price
# 0         1    iPhone 14   799.0
# 1         2      iMac 15  1299.0
# 3         4  Airpods Pro     NaN
# 4         5       iWatch   499.0

# %%
df3['price'].mean()
# Out:
# 865.6666666666666

# %%
df3['price'].fillna(df3['price'].mean(), inplace=True)
df3
# Out:
# <ipython-input-11-f4ffe0a3e853>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df3['price'].fillna(df3['price'].mean(), inplace=True)
#    order_id      product        price
# 0         1    iPhone 14   799.000000
# 1         2      iMac 15  1299.000000
# 3         4  Airpods Pro   865.666667
# 4         5       iWatch   499.000000

# %%
data4 = {
        'order_id': [1, 2, 3, 4, 5],
        'product': ['iPhone 14', 'iMac 15', np.nan, 'Airpods Pro', 'iWatch'],
        'price' : [799, 1299, np.nan, np.nan, 499]
        }

df4 = pd.DataFrame(data3)
df4
# Out:
#    order_id      product   price
# 0         1    iPhone 14   799.0
# 1         2      iMac 15  1299.0
# 2         3          NaN     NaN
# 3         4  Airpods Pro     NaN
# 4         5       iWatch   499.0

# %%
df4.dropna(axis=0)
# Out:
#    order_id    product   price
# 0         1  iPhone 14   799.0
# 1         2    iMac 15  1299.0
# 4         5     iWatch   499.0

# %%
df4.dropna(axis=1)
# Out:
#    order_id
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5

# %%
# Changing column names and data types

# %%
df3['price'].dtypes
# Out:
# dtype('float64')

# %%
df3['order_id'].astype('float')
# Out:
# 0    1.0
# 1    2.0
# 3    4.0
# 4    5.0
# Name: order_id, dtype: float64
